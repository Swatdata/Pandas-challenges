# %%
import pandas as pd #orders_qu and products_mecl from downloads has been used here below

# %%
#products_mecl.csv
path="/content/products_mecl.csv"
products_mecl=pd.read_csv(path)

#orders_brands
path="/content/orders_brands.csv"
orders_brands=pd.read_csv(path)

# brands_cl.csv
url = "https://drive.google.com/file/d/1XGyabaa4mAkjixMk3XPgx_14OoSse3rs/view?usp=sharing" 
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
brands = pd.read_csv(path)

# %%
orders_qu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60911 entries, 0 to 60910
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                60911 non-null  int64
#  1   order_id          60911 non-null  int64
#  2   product_quantity  60911 non-null  int64
#  3   sku               60911 non-null  object
#  4   unit_price        60911 non-null  float64
#  5   date              60911 non-null  object
#  6   created_date      60911 non-null  object
#  7   total_paid        60911 non-null  float64
#  8   state             60911 non-null  object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 4.2+ MB

# %%
products_mecl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10157 entries, 0 to 10156
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       10157 non-null  object
#  1   name      10157 non-null  object
#  2   desc      10151 non-null  object
#  3   price     10157 non-null  float64
#  4   in_stock  10157 non-null  int64
#  5   type      10110 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 476.2+ KB

# %%
len(list(orders_qu["order_id"].unique()))
# Out:
# 42569

# %%
dc=orders_brands.merge(products_mecl, how='left')

# %%
dc["discount"]= (dc['price']- dc['unit_price'])
dc
# Out:
#             id  order_id  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929     2565.99
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 60906  1649446    527042                 1    APP0927       13.99
# 60907  1649512    527070                 2    APP0698        9.99
# 60908  1649522    527074                 2    APP0698        9.99
# 60909  1649565    527096                 3    APP0698        9.99
# 60910  1649593    527112                 1    APP0698        9.99
#
#                       date         created_date  total_paid      state short  \
# 0      2017-01-01 01:46:16  2017-01-01 01:51:47       51.48  Completed   OWC
# ...

# %%
dc.drop(dc[(dc['discount']<0)].index,inplace=True)
dc
# Out:
#             id  order_id  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929     2565.99
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 60906  1649446    527042                 1    APP0927       13.99
# 60907  1649512    527070                 2    APP0698        9.99
# 60908  1649522    527074                 2    APP0698        9.99
# 60909  1649565    527096                 3    APP0698        9.99
# 60910  1649593    527112                 1    APP0698        9.99
#
#                       date         created_date  total_paid      state short  \
# 0      2017-01-01 01:46:16  2017-01-01 01:51:47       51.48  Completed   OWC
# ...

# %%
dc.drop(dc[(dc['discount']==0)].index,inplace=True)
dc
# Out:
#             id  order_id  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929     2565.99
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 60906  1649446    527042                 1    APP0927       13.99
# 60907  1649512    527070                 2    APP0698        9.99
# 60908  1649522    527074                 2    APP0698        9.99
# 60909  1649565    527096                 3    APP0698        9.99
# 60910  1649593    527112                 1    APP0698        9.99
#
#                       date         created_date  total_paid      state short  \
# 0      2017-01-01 01:46:16  2017-01-01 01:51:47       51.48  Completed   OWC
# ...

# %%
dc['percent']=dc['unit_price']/dc['price']*100
dc
# Out:
#             id  order_id  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929     2565.99
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 60906  1649446    527042                 1    APP0927       13.99
# 60907  1649512    527070                 2    APP0698        9.99
# 60908  1649522    527074                 2    APP0698        9.99
# 60909  1649565    527096                 3    APP0698        9.99
# 60910  1649593    527112                 1    APP0698        9.99
#
#                       date         created_date  total_paid      state short  \
# 0      2017-01-01 01:46:16  2017-01-01 01:51:47       51.48  Completed   OWC
# ...

# %%
dc.drop(dc[(dc['percent']>99.9)].index,inplace=True)
dc
# Out:
#             id  order_id  product_quantity        sku  unit_price  \
# 0      1119116    299545                 1    OWC0100       47.49
# 1      1119119    299546                 1    IOT0014       18.99
# 2      1119120    295347                 1    APP0700       72.19
# 3      1119126    299549                 1    PAC0929     2565.99
# 4      1119134    299556                 1  CRU0039-A       60.90
# ...        ...       ...               ...        ...         ...
# 60906  1649446    527042                 1    APP0927       13.99
# 60907  1649512    527070                 2    APP0698        9.99
# 60908  1649522    527074                 2    APP0698        9.99
# 60909  1649565    527096                 3    APP0698        9.99
# 60910  1649593    527112                 1    APP0698        9.99
#
#                       date         created_date  total_paid      state short  \
# 0      2017-01-01 01:46:16  2017-01-01 01:51:47       51.48  Completed   OWC
# ...

# %%
len(wo.order_id.unique())
# Out:
# 42569

# %%
from google.colab import files
#merged_discount
dc.to_csv("merged_discount.csv", index=False)
files.download("merged_discount.csv")

# %%
wo.discount.describe()
# Out:
# count    55849.000000
# mean        30.358589
# std         68.725473
# min       -174.618000
# 25%          5.550000
# 50%         15.000000
# 75%         32.440000
# max       1320.000000
# Name: discount, dtype: float64

# %%
#https://ourcodingclub.github.io/tutorials/pandas-python-intro/#creating plots
